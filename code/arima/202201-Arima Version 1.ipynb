# %% [markdown]
# ## Get data

# %% [markdown]
# ### Get data from yfinance

# %%
from pandas_datareader import data as pdr
from datetime import date
import yfinance as yf
yf.pdr_override()
import pandas as pd

ticker_list=["AAPL", "MSFT", "AMZN", "FB", "TSLA" "NVDA", "GOOG", "GOOGL", "CSCO", "AVGO"]
today = date.today()
# We can get data by our choice by giving days bracket
start_date= "2013-01-01"
end_date="2020-11-30"

files=[]
def getData(ticker):
    data = pdr.get_data_yahoo(ticker, start=start_date, end=today)
    # dataname= ticker+"_"+str(today)
    files.append((data,ticker))
    
for tik in ticker_list:
    getData(tik)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Setup firebase

# %%
import firebase_admin

cred_obj = firebase_admin.credentials.Certificate('../../fyp2022-stockpriceprediction-firebase-adminsdk-ku62m-f9ed330292.json')
fyp_app = firebase_admin.initialize_app(cred_obj, {
	'databaseURL':"https://fyp2022-stockpriceprediction-default-rtdb.asia-southeast1.firebasedatabase.app/",
	'storageBucket': 'fyp2022-stockpriceprediction.appspot.com'
	})

# %% [markdown]
# ### Upload data into firebase

# %%
from firebase_admin import db
from datetime import datetime as dt

for file in files:
    
    tick = file[1]
    data = file[0]
    data['Ticker'] = tick
    
    #convert date index to string, as firebsae cant have datetime as an index
    data.index = data.index.strftime("%Y-%m-%d")
    
    #convert the dataframe to json/dictionary
    data_dict = data.to_dict(orient="index")
    
    #upload it to the database
    ref = db.reference("/data/"+tick)
    ref.set(data_dict)

# %% [markdown]
# ### Get data from firebase database

# %%
from matplotlib import pyplot as plt
from firebase_admin import db
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
ref = db.reference("/data")
data = ref.get()

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import math
from zipfile import ZipFile
import os
from firebase_admin import storage
from sklearn.metrics import mean_squared_error
tf.debugging.set_log_device_placement(True)

def get_all_file_paths(directory):
  
    # initializing empty file paths list
    file_paths = []
  
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory):
        for filename in files:
            # join the two strings in order to form the full filepath.
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
  
    # returning all file paths
    return file_paths



try:
  # Specify an invalid GPU device
  #with tf.device('/device:GPU:2'):
  
  with tf.device('/device:GPU:2'):
    for tick, stock_data in data.items():
      df = pd.DataFrame(stock_data).T
      df = df.reset_index()['Close']
      scaler = MinMaxScaler(feature_range=(0,1))
      df=scaler.fit_transform(np.array(df).reshape(-1,1))
      train_data = df[:int(0.9*len(df))]
      test_data = df[int(0.9*len(df)):]
      train_data = train_data.reshape(-1,1)
      test_data = test_data.reshape(-1,1)
      
      def create_dataset(dataset, time_step=1):
          dataX, dataY = [], []
          for i in range(len(dataset)-time_step-1):
              a = dataset[i:(i+time_step), 0]
              dataX.append(a)
              dataY.append(dataset[i + time_step, 0])
          return np.array(dataX), np.array(dataY)
      time_step = 100
      X_train, y_train = create_dataset(train_data, time_step)
      X_test, ytest = create_dataset(test_data, time_step)
      
      X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
      X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
      
      model=Sequential()
      model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
      model.add(LSTM(50,return_sequences=True))
      model.add(LSTM(50))
      model.add(Dense(1))
      model.compile(loss='mean_squared_error',optimizer='adam')
      history = model.fit(X_train, y_train,epochs=10)
      
      
      # calling function to get all file paths in the directory
      fileName = tick + "_model"
      model.save(fileName)
      file_paths = get_all_file_paths(fileName)

      #took help from this: https://www.geeksforgeeks.org/working-zip-files-python/
      with ZipFile(fileName + ".zip",'w') as zip:
              # writing each file one by one
              for file in file_paths:
                  zip.write(file)
      
      
      bucket = storage.bucket()
      blob = bucket.blob(fileName)
      blob.upload_from_filename(fileName+".zip")

      # Opt : if you want to make public access from the URL
      #blob.make_public()
    # checking whether folder exists or not
    folder_path = fileName
    if os.path.exists(folder_path):

        # checking whether the folder is empty or not
        if len(os.listdir(folder_path)) == 0:
            # removing the file using the os.remove() method
            os.rmdir(folder_path)
        else:
            # messaging saying folder not empty
            print("Folder is not empty")
    else:
        # file not found message
        print("File not found in the directory")
      
except RuntimeError as e:
  print(e)
# Out:
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DiagPart in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DiagPart in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DiagPart in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AnonymousIteratorV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Epoch 1/10
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  1/61 [..............................] - ETA: 2:08 - loss: 0.0834Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  3/61 [>.............................] - ETA: 1s - loss: 0.0641  Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  5/61 [=>............................] - ETA: 1s - loss: 0.0463Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  7/61 [==>...........................] - ETA: 1s - loss: 0.0355Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  9/61 [===>..........................] - ETA: 1s - loss: 0.0302Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 11/61 [====>.........................] - ETA: 1s - loss: 0.0265Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 13/61 [=====>........................] - ETA: 1s - loss: 0.0231Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 15/61 [======>.......................] - ETA: 1s - loss: 0.0204Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 17/61 [=======>......................] - ETA: 1s - loss: 0.0189Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 19/61 [========>.....................] - ETA: 1s - loss: 0.0173Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 21/61 [=========>....................] - ETA: 1s - loss: 0.0156Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 23/61 [==========>...................] - ETA: 1s - loss: 0.0144Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 25/61 [===========>..................] - ETA: 1s - loss: 0.0135Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 27/61 [============>.................] - ETA: 1s - loss: 0.0126Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 29/61 [=============>................] - ETA: 1s - loss: 0.0118Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 31/61 [==============>...............] - ETA: 0s - loss: 0.0111Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 33/61 [===============>..............] - ETA: 0s - loss: 0.0105Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 35/61 [================>.............] - ETA: 0s - loss: 0.0099Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 37/61 [=================>............] - ETA: 0s - loss: 0.0094Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 39/61 [==================>...........] - ETA: 0s - loss: 0.0090Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 41/61 [===================>..........] - ETA: 0s - loss: 0.0086Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 43/61 [====================>.........] - ETA: 0s - loss: 0.0082Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 45/61 [=====================>........] - ETA: 0s - loss: 0.0079Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 47/61 [======================>.......] - ETA: 0s - loss: 0.0075Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 49/61 [=======================>......] - ETA: 0s - loss: 0.0072Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 51/61 [========================>.....] - ETA: 0s - loss: 0.0070Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 53/61 [=========================>....] - ETA: 0s - loss: 0.0067Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 55/61 [==========================>...] - ETA: 0s - loss: 0.0065Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 57/61 [===========================>..] - ETA: 0s - loss: 0.0063Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 59/61 [============================>.] - ETA: 0s - loss: 0.0061Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 61/61 [==============================] - 4s 31ms/step - loss: 0.0059
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 2/10
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  1/61 [..............................] - ETA: 1s - loss: 2.4419e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  3/61 [>.............................] - ETA: 1s - loss: 2.5959e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  5/61 [=>............................] - ETA: 1s - loss: 2.1848e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  7/61 [==>...........................] - ETA: 1s - loss: 2.0101e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  9/61 [===>..........................] - ETA: 1s - loss: 2.5813e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#
-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 47/61 [======================>.......] - ETA: 0s - loss: 3.1923e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 49/61 [=======================>......] - ETA: 0s - loss: 3.1236e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 51/61 [========================>.....] - ETA: 0s - loss: 3.1149e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 53/61 [=========================>....] - ETA: 0s - loss: 3.0644e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 55/61 [==========================>...] - ETA: 0s - loss: 3.0965e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 57/61 [===========================>..] - ETA: 0s - loss: 3.0746e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 59/61 [============================>.] - ETA: 0s - loss: 3.1592e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 61/61 [==============================] - 2s 30ms/step - loss: 3.1985e-04
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 4/10
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  1/61 [..............................] - ETA: 1s - loss: 2.9601e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  3/61 [>.............................] - ETA: 1s - loss: 3.1407e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  5/61 [=>............................] - ETA: 1s - loss: 2.3919e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  7/61 [==>...........................] - ETA: 1s - loss: 2.8743e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
#  9/61 [===>..........................] - ETA: 1s - loss: 2.8100e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 11/61 [====>.........................] - ETA: 1s - loss: 2.8454e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 13/61 [=====>........................] - ETA: 1s - loss: 3.3383e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 15/61 [======>.......................] - ETA: 1s - loss: 3.1654e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 17/61 [=======>......................] - ETA: 1s - loss: 3.2153e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 19/61 [========>.....................] - ETA: 1s - loss: 3.1606e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 21/61 [=========>....................] - ETA: 1s - loss: 3.1798e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# 23/61 [==========>...................] - ETA: 1s - loss: 3.2814e-04Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_train_function_81717 in device /job:localhost/replica:0/task:0/device:GPU:0
# ...
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# WARNING:absl:Found untraced functions such as lstm_cell_30_layer_call_and_return_conditional_losses, lstm_cell_30_layer_call_fn, lstm_cell_31_layer_call_and_return_conditional_losses, lstm_cell_31_layer_call_fn, lstm_cell_32_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# Executing op StaticRegexFullMatch in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Select in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StringJoin in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ShardedFilename in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op SaveV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Pack in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MergeV2Checkpoints in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Assets written to: NVDA_model\assets
# INFO:tensorflow:Assets written to: NVDA_model\assets
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0

# %%
test_predict=model.predict(X_test)
test_predict=scaler.inverse_transform(test_predict)

ytest = scaler.inverse_transform(ytest.reshape(-1,1))
error = math.sqrt(mean_squared_error(ytest,test_predict))
error
# Out:
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AnonymousIteratorV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_predict_function_55862 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_predict_function_55862 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_predict_function_55862 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_predict_function_55862 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DeleteIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# 5.177896528916009

# %%
train_predict=model.predict(X_train)
train_predict=scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train.reshape(-1,1))
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 3.0307830607276087

# %%
plt.plot(test_predict)
plt.plot(ytest)
plt.show()

# %%
# specifying the zip file name
file_name = "AAPL_model.zip"
  
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zip:
    # printing all the contents of the zip file
    zip.printdir()
  
    # extracting all the files
    print('Extracting all the files now...')
    zip.extractall()
    print('Done!')
# Out:
# File Name                                             Modified             Size
# AAPL_model/keras_metadata.pb                   2022-01-12 19:16:08        17068
# AAPL_model/saved_model.pb                      2022-01-12 19:16:08      2382689
# AAPL_model/variables/variables.data-00000-of-00001 2022-01-12 19:16:08       618372
# AAPL_model/variables/variables.index           2022-01-12 19:16:08         2731
# Extracting all the files now...
# Done!

# %%
blob.upload_from_filename(fileName+".zip")
